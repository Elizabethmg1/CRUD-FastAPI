# %%
import requests

# %%
r = requests.get("http://localhost:8000/empleados/1")
r.json()
# Out:
# {'dni': '444555666',
#  'nombre_completo': 'Mariana Gomez',
#  'observaciones': 'Observaciones',
#  'is_active': False,
#  'id': 1,
#  'created_at': '2026-05-14T20:18:40.242957',
#  'updated_at': '2026-05-14T20:19:54.657036'}

# %%
url = "http://localhost:8000/empleados/1"
payload = {"dni": "444555666", "nombre_completo": "Mariana Gomez", "observaciones": "Observaciones", "is_active": False}
r = requests.patch(url, json=payload)
r.json()
# Out:
# {'dni': '444555666',
#  'nombre_completo': 'Mariana Gomez',
#  'observaciones': 'Observaciones',
#  'is_active': False,
#  'id': 1,
#  'created_at': '2026-05-14T20:18:40.242957',
#  'updated_at': '2026-05-14T20:19:54.657036'}

# %%
url = "http://localhost:8000/empleados/1"
r = requests.delete(url)
r.status_code
# Out:
# 204

# %%
# Out:
# 204
